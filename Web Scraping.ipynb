# %%
#pip install requests

# %%
#pip install bs4
import requests
from bs4 import BeautifulSoup

# %%
url ='https://www.flipkart.com/search?q=samsung+mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=samsung+mobiles%7CMobiles&requestId=fbddc761-ea74-418c-9921-7a5a02a1757e&as-searchtext=sam'

page = requests.get(url)
data = page.text
soup = BeautifulSoup(data, 'html.parser')

# %%
#res

# %%
#res.content

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find_all('div',class_="_4rR01T")
# Out:
# [<div class="_4rR01T">SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Guru Music 2</div>,
#  <div class="_4rR01T">SAMSUNG Guru Music 2</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy M14 5G (Icy Silver, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F14 5G (B.A.E. Purple, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Guru Music 2</div>,
#  <div class="_4rR01T">SAMSUNG GURU MUSIC 2</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy M14 5G (Smoky Teal, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F34 5G (Mystic Green, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy M14 5G (Berry Blue, 128 GB)</div>,
# ...

# %%
rows=soup.findAll('div', class_="_30jeq3 _1_WHN1")

# %%
l2=[]
for row in rows:
    l2.append(row.getText())
    
l2
# Out:
# ['₹10,999',
#  '₹2,880',
#  '₹2,890',
#  '₹15,088',
#  '₹14,990',
#  '₹10,999',
#  '₹2,424',
#  '₹2,299',
#  '₹14,990',
#  '₹16,999',
#  '₹14,990',
#  '₹16,999',
#  '₹19,999',
#  '₹14,809',
#  '₹11,999',
#  '₹8,122',
#  '₹13,990',
#  '₹13,990',
#  '₹2,450',
#  '₹21,999',
#  '₹14,990',
#  '₹19,999',
#  '₹8,050',
#  '₹16,999']

# %%
row1=soup.find_all('div',class_="_4rR01T")

# %%
l1=[]
for row in row1:
    l1.append(row.getText())

l1
# Out:
# ['SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)',
#  'SAMSUNG Guru Music 2',
#  'SAMSUNG Guru Music 2',
#  'SAMSUNG Galaxy M14 5G (Icy Silver, 128 GB)',
#  'SAMSUNG Galaxy F14 5G (B.A.E. Purple, 128 GB)',
#  'SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)',
#  'SAMSUNG Guru Music 2',
#  'SAMSUNG GURU MUSIC 2',
#  'SAMSUNG Galaxy M14 5G (Smoky Teal, 128 GB)',
#  'SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)',
#  'SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)',
#  'SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)',
#  'SAMSUNG Galaxy F34 5G (Mystic Green, 128 GB)',
#  'SAMSUNG Galaxy M14 5G (Berry Blue, 128 GB)',
#  'SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)',
#  'SAMSUNG Galaxy M04 (Dark Blue, 64 GB)',
#  'SAMSUNG Galaxy F14 5G (B.A.E. Purple, 128 GB)',
#  'SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)',
#  'SAMSUNG Guru Music 2',
#  'SAMSUNG Galaxy F34 5G (Electric Black, 128 GB)',
#  'SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)',
#  'SAMSUNG Galaxy F34 5G (Electric Black, 128 GB)',
# ...

# %%
s={l1[i]:l2[i] for i in range(len(l2))}
s
# Out:
# {'SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)': '₹10,999',
#  'SAMSUNG Guru Music 2': '₹2,450',
#  'SAMSUNG Galaxy M14 5G (Icy Silver, 128 GB)': '₹15,088',
#  'SAMSUNG Galaxy F14 5G (B.A.E. Purple, 128 GB)': '₹13,990',
#  'SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)': '₹10,999',
#  'SAMSUNG GURU MUSIC 2': '₹2,299',
#  'SAMSUNG Galaxy M14 5G (Smoky Teal, 128 GB)': '₹14,990',
#  'SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)': '₹16,999',
#  'SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)': '₹13,990',
#  'SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)': '₹16,999',
#  'SAMSUNG Galaxy F34 5G (Mystic Green, 128 GB)': '₹19,999',
#  'SAMSUNG Galaxy M14 5G (Berry Blue, 128 GB)': '₹14,809',
#  'SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)': '₹11,999',
#  'SAMSUNG Galaxy M04 (Dark Blue, 64 GB)': '₹8,122',
#  'SAMSUNG Galaxy F34 5G (Electric Black, 128 GB)': '₹19,999',
#  'SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)': '₹14,990',
#  'SAMSUNG Galaxy M04 (Light Green, 64 GB)': '₹8,050',
# ...
